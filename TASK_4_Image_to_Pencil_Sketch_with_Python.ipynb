# %% [markdown]
# # LETS GROW MORE - DATA SCIENCE INTERNSHIP

# %% [markdown]
# # TASK 4 IMAGE TO PENCIL SKETCH USING PYTHON

# %% [markdown]
# ### AUTHOR - Amitabh Kumar Vishwakarma

# %% [markdown]
# ### **IMPORTING LIBRARIES**

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### **LOADING THE IMAGE**

# %%
img = cv2.imread("ami.jpg")
img = cv2.resize(img,(800,800))
i_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(i_rgb)

# %% [markdown]
# ### **CONVERTING THE IMAGE TO GREYSCALE**

# %%
from IPython.display import display

# %%
grey_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
display(Image.fromarray(grey_img))
# Out:
# <PIL.Image.Image image mode=L size=800x800 at 0x7F3BACBA9E10>

# %% [markdown]
# ### **CONVERTING THE IMAGE TO NEGATIVE**

# %%
invt_img = cv2.bitwise_not(grey_img)
display(Image.fromarray(invt_img))
# Out:
# <PIL.Image.Image image mode=L size=800x800 at 0x7F3BAAE71E50>

# %% [markdown]
# ### **SMOOTHENING THE IMAGE**

# %%
blur_img = cv2.GaussianBlur(invt_img, (5,5), 0, 0)
display(Image.fromarray(blur_img))
# Out:
# <PIL.Image.Image image mode=L size=800x800 at 0x7F3BAAE80850>

# %% [markdown]
# ### **CREATING THE PENCIL SKETCH FROM IMAGE**

# %%
invt_blur_img = 255 - blur_img
sketch = cv2.divide(grey_img, invt_blur_img, scale= 250.0)
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=L size=800x800 at 0x7F3BAAE71490>

# %% [markdown]
# ### **CONCLUSION - COMPARING THE SKETCH AND ORIGINAL IMAGE**

# %%
i_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(i_rgb)
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=L size=800x800 at 0x7F3BAADBFB10>
